# %%
import torch
from torch.autograd import Variable
import numpy as np
import torch.functional as F
import torch.nn.functional as F
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
corpus = re.sub(r'[\d\t,.?!]', '', open('Corpus_sentences_in_Russian.txt', 'r', encoding='utf8').read()).split('\n')[:-1]
corpus[:10]
# Out:
# ['На болотах оставался ещё лёд но на берегах реки появилась трава',
#  'Он ловко поддел концом ножа замочки и они отскочили',
#  'Ваня раскрыл было рот но понял что что-то не так и промолчал',
#  'Сделав мне знак помолчать он приложил ухо к двери',
#  'Я сделала шаг навстречу: приехала к ней попросив выслушать меня',
#  'Дорога ведет в глухой лес петляя по склонам',
#  'Не поручайте мужу ухаживать за рыбками в аквариуме он обязательно забудет',
#  'Выходя замуж ты надеялась обрести спокойствие уютный дом крепкую семью',
#  'И не надо ставить это целью всей своей жизни',
#  'У нас в Волгограде многие придерживаются иной точки зрения']

# %%
def tokenize_corpus(corpus):
    tokens = [x.split() for x in corpus]
    return tokens

tokenized_corpus = tokenize_corpus(corpus)
print(tokenized_corpus)
# Out:
# [['На', 'болотах', 'оставался', 'ещё', 'лёд', 'но', 'на', 'берегах', 'реки', 'появилась', 'трава'], ['Он', 'ловко', 'поддел', 'концом', 'ножа', 'замочки', 'и', 'они', 'отскочили'], ['Ваня', 'раскрыл', 'было', 'рот', 'но', 'понял', 'что', 'что-то', 'не', 'так', 'и', 'промолчал'], ['Сделав', 'мне', 'знак', 'помолчать', 'он', 'приложил', 'ухо', 'к', 'двери'], ['Я', 'сделала', 'шаг', 'навстречу:', 'приехала', 'к', 'ней', 'попросив', 'выслушать', 'меня'], ['Дорога', 'ведет', 'в', 'глухой', 'лес', 'петляя', 'по', 'склонам'], ['Не', 'поручайте', 'мужу', 'ухаживать', 'за', 'рыбками', 'в', 'аквариуме', 'он', 'обязательно', 'забудет'], ['Выходя', 'замуж', 'ты', 'надеялась', 'обрести', 'спокойствие', 'уютный', 'дом', 'крепкую', 'семью'], ['И', 'не', 'надо', 'ставить', 'это', 'целью', 'всей', 'своей', 'жизни'], ['У', 'нас', 'в', 'Волгограде', 'многие', 'придерживаются', 'иной', 'точки', 'зрения'], ['Очень', 'тогда', 'злые', 'попадались', 'люди'], ['На', 'привале', 'у', 'озера', 'юный', 'турист', 'вручил', 'товарищам', 'ведро', 'и', 'кувшин'], ['Наживка', 'на', 'которую', 'он', 'ловил', 'рыбу', 'быстро', 'закончилась'], ['Мне', 'было', 'лень', 'идти', 'на', 'стоянку', 'и', 'сметать', 'снег', 'с', 'машины'], ['Город', 'раскинувшийся', 'вдоль', 'реки', 'состоял', 'из', 'двух', 'частей'], ['В', 'каждом', 'углу', 'комнаты', 'сидели', 'по', 'две', 'кошки'], ['Здесь', 'потребуется', 'врач', 'который', 'будет', 'лечить', 'заболевших', 'в', 'экспедиции'], ['У', 'моего', 'отца', 'был', 'счёт', 'в', 'швейцарском', 'банке', 'он', 'был', 'лесоторговец'], ['Количество', 'денег', 'в', 'обороте', 'выросло', 'благодаря', 'союзу', 'с', 'американским', 'банком'], ['Возможности', 'этих', 'перемен', 'будут', 'обсуждаться', 'в', 'Париже', 'летом', 'будущего', 'года'], ['Применение', 'микросхемы', 'даст', 'возможность', 'уменьшить', 'вес', 'бытовой', 'электроники'], ['Однако', 'здесь', 'есть', 'и', 'свои', 'актуальные', 'проблемы'], ['Если', 'мы', 'позволим', 'этим', 'людям', 'уйти', 'наши', 'проекты', 'станут', 'гораздо', 'беднее'], ['Он', 'признаёт', 'право', 'каждого', 'жить', 'так', 'как', 'ему', 'удобно'], ['Власть', 'судов', 'была', 'такой', 'узкой', 'что', 'они', 'ничего', 'не', 'решали'], ['Тема', 'эта', 'в', 'то', 'время', 'была', 'новой', 'для', 'многих'], ['Каждое', 'утро', 'на', 'самый', 'верх', 'крыши', 'МГУ', 'поднимается', 'симпатичная', 'научная', 'сотрудница'], ['Музыканты', 'играли', 'на', 'похоронах', 'разгружали', 'вагоны', 'жили', 'бедно'], ['Зоопарк', '―', 'это', 'кусочек', 'другого', 'мира', 'находящийся', 'в', 'самом', 'центре', 'нашего', 'района'], ['Взяв', 'с', 'собой', 'фотоаппарат', 'вся', 'семья', 'поехала', 'в', 'парк', 'на', 'пикник'], ['Телята', 'быстро', 'росли', 'превращаясь', 'в', 'ласковых', 'коров'], ['Он', 'стал', 'плохо', 'спать', 'капризничать', 'в', 'детском', 'саду'], ['Чтобы', 'придать', 'объем', 'тонким', 'волосам', 'нанесите', 'на', 'них', 'лечебную', 'маску'], ['У', 'тебя', 'впереди', 'замечательный', 'день', 'полный', 'приятных', 'событий'], ['Мама', 'брала', 'меня', 'с', 'собой', 'и', 'мы', 'сдав', 'молоко', 'ехали', 'гулять'], ['От', 'смерти', 'его', 'спасла', 'собака', 'приносившая', 'ему', 'еду'], ['Судя', 'по', 'огромному', 'расходу', 'воды', 'они', 'купали', 'слонов'], ['Тому', 'кто', 'желает', 'невозможного', 'объяснят:', '"Близок', 'локоть', 'да', 'не', 'укусишь"'], ['Когда', 'она', 'в', 'самолёте', 'летела', 'домой', 'читать', 'не', 'было', 'сил'], ['Володя', 'каким-то', 'образом', 'узнал', 'то', 'чего', 'ему', 'не', 'надо', 'было', 'знать'], ['Перед', 'ним', 'снова', 'была', 'прежняя', 'Маша', 'которую', 'он', 'знал', 'и', 'любил'], ['Мне', 'нравится', 'сын', 'коллеги', 'который', 'недавно', 'заходил', 'в', 'наш', 'отдел'], ['У', 'мамы', 'есть', 'подруга', 'которая', 'живёт', 'прямо', 'напротив', 'здания', 'театра'], ['Душа', 'требовала', 'красоты', 'и', 'Николай', 'Фомин', 'украсил', 'свой', 'дом', 'резьбой'], ['За', 'углом', '―', 'Морской', 'музей', 'с', 'бесчисленными', 'моделями', 'кораблей', 'старинн ...

# %%
vocabulary = []
for sentence in tokenized_corpus:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
word2idx
# Out:
# {'На': 0,
#  'болотах': 1,
#  'оставался': 2,
#  'ещё': 3,
#  'лёд': 4,
#  'но': 5,
#  'на': 6,
#  'берегах': 7,
#  'реки': 8,
#  'появилась': 9,
#  'трава': 10,
#  'Он': 11,
#  'ловко': 12,
#  'поддел': 13,
#  'концом': 14,
#  'ножа': 15,
#  'замочки': 16,
#  'и': 17,
#  'они': 18,
#  'отскочили': 19,
#  'Ваня': 20,
#  'раскрыл': 21,
#  'было': 22,
#  'рот': 23,
#  'понял': 24,
#  'что': 25,
#  'что-то': 26,
#  'не': 27,
#  'так': 28,
#  'промолчал': 29,
#  'Сделав': 30,
#  'мне': 31,
#  'знак': 32,
#  'помолчать': 33,
#  'он': 34,
#  'приложил': 35,
#  'ухо': 36,
#  'к': 37,
#  'двери': 38,
#  'Я': 39,
#  'сделала': 40,
#  'шаг': 41,
#  'навстречу:': 42,
#  'приехала': 43,
#  'ней': 44,
#  'попросив': 45,
#  'выслушать': 46,
#  'меня': 47,
#  'Дорога': 48,
#  'ведет': 49,
#  'в': 50,
#  'глухой': 51,
#  'лес': 52,
#  'петляя': 53,
#  'по': 54,
#  'склонам': 55,
#  'Не': 56,
#  'поручайте': 57,
#  'мужу': 58,
#  'ухаживать': 59,
#  'за': 60,
#  'рыбками': 61,
#  'аквариуме': 62,
#  'обязательно': 63,
#  'забудет': 64,
#  'Выходя': 65,
#  'замуж': 66,
#  'ты': 67,
#  'надеялась': 68,
#  'обрести': 69,
#  'спокойствие': 70,
#  'уютный': 71,
#  'дом': 72,
#  'крепкую': 73,
#  'семью': 74,
#  'И': 75,
#  'надо': 76,
#  'ставить': 77,
#  'это': 78,
#  'целью': 79,
#  'всей': 80,
#  'своей': 81,
#  'жизни': 82,
#  'У': 83,
#  'нас': 84,
#  'Волгограде': 85,
#  'многие': 86,
#  'придерживаются': 87,
#  'иной': 88,
#  'точки': 89,
#  'зрения': 90,
#  'Очень': 91,
#  'тогда': 92,
#  'злые': 93,
#  'попадались': 94,
#  'люди': 95,
#  'привале': 96,
#  'у': 97,
#  'озера': 98,
#  'юный': 99,
#  'турист': 100,
#  'вручил': 101,
#  'товарищам': 102,
#  'ведро': 103,
#  'кувшин': 104,
#  'Наживка': 105,
#  'которую': 106,
#  'ловил': 107,
#  'рыбу': 108,
#  'быстро': 109,
#  'закончилась': 110,
#  'Мне': 111,
#  'лень': 112,
#  'идти': 113,
#  'стоянку': 114,
#  'сметать': 115,
#  'снег': 116,
#  'с': 117,
#  'машины': 118,
#  'Город': 119,
#  'раскинувшийся': 120,
#  'вдоль': 121,
#  'состоял': 122,
#  'из': 123,
#  'двух': 124,
#  'частей': 125,
#  'В': 126,
#  'каждом': 127,
#  'углу': 128,
#  'комнаты': 129,
#  'сидели': 130,
#  'две': 131,
#  'кошки': 132,
#  'Здесь': 133,
#  'потребуется': 134,
#  'врач': 135,
#  'который': 136,
#  'будет': 137,
#  'лечить': 138,
#  'заболевших': 139,
#  'экспедиции': 140,
#  'моего': 141,
#  'отца': 142,
#  'был': 143,
#  'счёт': 144,
#  'швейцарском': 145,
#  'банке': 146,
#  'лесоторговец': 147,
#  'Количество': 148,
#  'денег': 149,
#  'обороте': 150,
#  'выросло': 151,
#  'благодаря': 152,
#  'союзу': 153,
#  'американским': 154,
#  'банком': 155,
#  'Возможности': 156,
#  'этих': 157,
#  'перемен': 158,
#  'будут': 159,
#  'обсуждаться': 160,
#  'Париже': 161,
#  'летом': 162,
#  'будущего': 163,
#  'года': 164,
#  'Применение': 165,
#  'микросхемы': 166,
#  'даст': 167,
#  'возможность': 168,
#  'уменьшить': 169,
#  'вес': 170,
#  'бытовой': 171,
#  'электроники': 172,
#  'Однако': 173,
#  'здесь': 174,
#  'есть': 175,
#  'свои': 176,
#  'актуальные': 177,
#  'проблемы': 178,
#  'Если': 179,
#  'мы': 180,
#  'позволим': 181,
#  'этим': 182,
#  'людям': 183,
#  'уйти': 184,
#  'наши': 185,
#  'проекты': 186,
#  'станут': 187,
#  'гораздо': 188,
#  'беднее': 189,
#  'признаёт': 190,
#  'право': 191,
#  'каждого': 192,
#  'жить': 193,
#  'как': 194,
#  'ему': 195,
#  'удобно': 196,
#  'Власть': 197,
#  'судов': 198,
#  'была': 199,
#  'такой': 200,
#  'узкой': 201,
#  'ничего': 202,
#  'решали': 203,
#  'Тема': 204,
#  'эта': 205,
#  'то': 206,
#  'время': 207,
#  'новой': 208,
#  'для': 209,
#  'многих': 210,
#  'Каждое': 211,
#  'утро': 212,
#  'самый': 213,
#  'верх': 214,
#  'крыши': 215,
#  'МГУ': 216,
#  'поднимается': 217,
#  'симпатичная': 218,
#  'научная': 219,
#  'сотрудница': 220,
#  'Музыканты': 221,
#  'играли': 222,
#  'похоронах': 223,
#  'разгружали': 224,
#  'вагоны': 225,
#  'жили': 226,
#  'бедно': 227,
#  'Зоопарк': 228,
#  '―': 229,
#  'кусочек': 230,
#  'другого': 231,
#  'мира': 232,
#  'находящийся': 233,
#  'самом': 234,
#  'центре': 235,
#  'нашего': 236,
#  'района': 237,
#  'Взяв': 238,
#  'собой': 239,
#  'фотоаппарат': 240,
#  'вся': 241,
#  'семья': 242,
#  'поехала': 243,
#  'парк': 244,
#  'пикник': 245,
#  'Телята': 246,
#  'росли': 247,
#  'превращаясь': 248,
#  'ласковых': 249,
#  'коров': 250,
#  'стал': 251,
#  'плохо': 252,
#  'спать': 253,
#  'капризничать': 254,
#  'детском': 255,
#  'саду': 256,
#  'Чтобы': 257,
#  'придать': 258,
#  'объем': 259,
#  'тонким': 260,
#  'волосам': 261,
#  'нанесите': 262,
#  'них': 263,
#  'лечебную': 264,
#  'маску': 265,
#  'тебя': 266,
#  'впереди': 267,
#  'замечательный': 268,
#  'день': 269,
#  'полный': 270,
#  'приятных': 271,
#  'событий': 272,
#  'Мама': 273,
#  'брала': 274,
#  'сдав': 275,
#  'молоко': 276,
#  'ехали': 277,
#  'гулять': 278,
#  'От': 279,
#  'смерти': 280,
#  'его': 281,
#  'спасла': 282,
#  'собака': 283,
#  'приносившая': 284,
#  'еду': 285,
#  'Судя': 286,
#  'огромному': 287,
#  'расходу': 288,
#  'воды': 289,
#  'купали': 290,
#  'слонов': 291,
#  'Тому': 292,
#  'кто': 293,
#  'желает': 294,
#  'невозможного': 295,
#  'объяснят:': 296,
#  '"Близок': 297,
#  'локоть': 298,
#  'да': 299,
#  'укусишь"': 300,
#  'Когда': 301,
#  'она': 302,
#  'самолёте': 303,
#  'летела': 304,
#  'домой': 305,
#  'читать': 306,
#  'сил': 307,
#  'Володя': 308,
#  'каким-то': 309,
#  'образом': 310,
#  'узнал': 311,
#  'чего': 312,
#  'знать': 313,
#  'Перед': 314,
#  'ним': 315,
#  'снова': 316,
#  'прежняя': 317,
#  'Маша': 318,
#  'знал': 319,
#  'любил': 320,
#  'нравится': 321,
#  'сын': 322,
#  'коллеги': 323,
#  'недавно': 324,
#  'заходил': 325,
#  'наш': 326,
#  'отдел': 327,
#  'мамы': 328,
#  'подруга': 329,
#  'которая': 330,
#  'живёт': 331,
#  'прямо': 332,
#  'напротив': 333,
#  'здания': 334,
#  'театра': 335,
#  'Душа': 336,
#  'требовала': 337,
#  'красоты': 338,
#  'Николай': 339,
#  'Фомин': 340,
#  'украсил': 341,
#  'свой': 342,
#  'резьбой': 343,
#  'За': 344,
#  'углом': 345,
#  'Морской': 346,
#  'музей': 347,
#  'бесчисленными': 348,
#  'моделями': 349,
#  'кораблей': 350,
#  'старинных': 351,
#  'современных': 352,
#  'Причиной': 353,
#  'аварии': 354,
#  'мобильный': 355,
#  'телефон': 356,
#  'отвлекал': 357,
#  'водителя': 358,
#  'от': 359,
#  'дороги': 360,
#  'Можно': 361,
#  'бросить': 362,
#  'дополнительные': 363,
#  'занятия': 364,
#  'даже': 365,
#  'школу': 366,
#  'можно': 367,
#  'Какие': 368,
#  'главные': 369,
#  'лекарства': 370,
#  'должны': 371,
#  'входить': 372,
#  'аптечку': 373,
#  'автомобилиста': 374,
#  'газовой': 375,
#  'плите': 376,
#  'стояла': 377,
#  'открытая': 378,
#  'кастрюля': 379,
#  'кипящей': 380,
#  'водой': 381,
#  'Автор': 382,
#  'принадлежит': 383,
#  'числу': 384,
#  'последних': 385,
#  'свидетелей': 386,
#  'страшных': 387,
#  'прошлого': 388,
#  'века': 389,
#  'лестнице': 390,
#  'сосед': 391,
#  'попросил': 392,
#  'говорить': 393,
#  'тише': 394,
#  'Этот': 395,
#  'роман': 396,
#  'захватывает': 397,
#  'читателя': 398,
#  'первой': 399,
#  'страницы': 400,
#  'держит': 401,
#  'до': 402,
#  'последней': 403,
#  'вопросе': 404,
#  'послышался': 405,
#  'упрёк': 406,
#  'командиру': 407,
#  'словно': 408,
#  'виновником': 409,
#  'происшедшего': 410,
#  'современном': 411,
#  'обществе': 412,
#  'школа': 413,
#  'оказывают': 414,
#  'большое': 415,
#  'влияние': 416,
#  'подростков': 417,
#  'студент': 418,
#  'получает': 419,
#  'только': 420,
#  'отличные': 421,
#  'оценки': 422,
#  'самого': 423,
#  'первого': 424,
#  'семестра': 425,
#  'числе': 426,
#  'возможных': 427,
#  'кандидатов': 428,
#  'называют': 429,
#  'депутата': 430,
#  'партии': 431,
#  'правых': 432,
#  'Зачем': 433,
#  'звонить': 434,
#  'если': 435,
#  'откликается': 436,
#  'спокойный': 437,
#  'женский': 438,
#  'голос': 439,
#  'Ирине': 440,
#  'досталась': 441,
#  'отдельная': 442,
#  'комната': 443,
#  'двухкомнатной': 444,
#  'квартире': 445,
#  'тот': 446,
#  'момент': 447,
#  'атмосфера': 448,
#  'наших': 449,
#  'посиделок': 450,
#  'внезапно': 451,
#  'сильно': 452,
#  'изменилась': 453,
#  'Товарищ': 454,
#  'генерал': 455,
#  'противник': 456,
#  'пробрался': 457,
#  'командный': 458,
#  'пункт': 459,
#  'Шею': 460,
#  'Лизы': 461,
#  'украшало': 462,
#  'ожерелье': 463,
#  'стоимостью': 464,
#  'тысяч': 465,
#  'долларов': 466,
#  'Ольгу': 467,
#  'Васильевну': 468,
#  'написано': 469,
#  'заявление': 470,
#  'полицию': 471,
#  'Что': 472,
#  'хочешь': 473,
#  'чтобы': 474,
#  'тебе': 475,
#  'повторили': 476,
#  'вопрос': 477,
#  'или': 478,
#  'ответ': 479,
#  'Но': 480,
#  'четыре': 481,
#  'я': 482,
#  'мог': 483,
#  'себя': 484,
#  'заставить': 485,
#  'сделать': 486,
#  'Педагог': 487,
#  'предъявляет': 488,
#  'одинаковые': 489,
#  'требования': 490,
#  'ко': 491,
#  'всем': 492,
#  'Они': 493,
#  'ели': 494,
#  'целый': 495,
#  'несчастные': 496,
#  'дети': 497,
#  'были': 498,
#  'очень': 499,
#  'голодны': 500,
#  'массаже': 501,
#  'тело': 502,
#  'расслабляется': 503,
#  'исчезает': 504,
#  'напряжение': 505,
#  'мышцах': 506,
#  'Стала': 507,
#  'стабильнее': 508,
#  'экономическая': 509,
#  'политическая': 510,
#  'обстановка': 511,
#  'расслабились': 512,
#  'Работы': 513,
#  'выполняет': 514,
#  'специалист': 515,
#  'исполнителя': 516,
#  'имеющий': 517,
#  'высокую': 518,
#  'квалификацию': 519,
#  'Во': 520,
#  'избежание': 521,
#  'ожогов': 522,
#  'нанести': 523,
#  'лицо': 524,
#  'небольшое': 525,
#  'количество': 526,
#  'защитного': 527,
#  'крема': 528,
#  'Государством': 529,
#  'предлагается': 530,
#  'установить': 531,
#  'ограничение': 532,
#  'скорость': 533,
#  'движения': 534,
#  'конверте': 535,
#  'вместе': 536,
#  'деньгами': 537,
#  'обнаружена': 538,
#  'записка': 539,
#  'угрозами': 540,
#  'используют': 541,
#  'этой': 542,
#  'прически': 543,
#  'фен': 544,
#  'Там': 545,
#  'недалеко': 546,
#  'кухонной': 547,
#  'сидел': 548,
#  'лис': 549,
#  'треугольной': 550,
#  'мордой': 551,
#  'может': 552,
#  'сильный': 553,
#  'вол': 554,
#  'впряжен': 555,
#  'сломанную': 556,
#  'повозку': 557,
#  'директора': 558,
#  'школы': 559,
#  'тонкий': 560,
#  'нюх': 561,
#  'талантливых': 562,
#  'педагогов': 563,
#  'умел': 564,
#  'любого': 565,
#  'сора': 566,
#  'извлекать': 567,
#  'информацию': 568,
#  'темноте': 569,
#  'Иван': 570,
#  'задел': 571,
#  'острый': 572,
#  'сук': 573,
#  'чуть': 574,
#  'порвал': 575,
#  'рукав': 576,
#  'сюжете': 577,
#  'этого': 578,
#  'фильма': 579,
#  'какие-то': 580,
#  'осы': 581,
#  'устраивают': 582,
#  'себе': 583,
#  'гнёзда': 584,
#  'дереве': 585,
#  'багажнике': 586,
#  'лопата': 587,
#  'лом': 588,
#  'грабли': 589,
#  'Существует': 590,
#  'легенда': 591,
#  'Ноев': 592,
#  'ковчег': 593,
#  'вынесло': 594,
#  'вершину': 595,
#  'горы': 596,
#  'Покуда': 597,
#  'нахожусь': 598,
#  'власти': 599,
#  'буду': 600,
#  'предметом': 601,
#  'ярых': 602,
#  'нападок': 603,
#  'соперников': 604,
#  'Ей': 605,
#  'хотелось': 606,
#  'выплеснуть': 607,
#  'чай': 608,
#  'бежевый': 609,
#  'Юлин': 610,
#  'пиджак': 611,
#  'сдерживалась': 612,
#  'Выбирая': 613,
#  'вязаную': 614,
#  'шапочку': 615,
#  'знайте': 616,
#  'лучше': 617,
#  'шапка': 618,
#  'цвета': 619,
#  'хаки': 620,
#  'шерсти': 621,
#  'филологическогом': 622,
#  'факультете': 623,
#  'студенты': 624,
#  'заметят': 625,
#  'явный': 626,
#  'крен': 627,
#  'сторону': 628,
#  'педагогики': 629,
#  'Думаю': 630,
#  'большой': 631,
#  'урон': 632,
#  'здоровью': 633,
#  'такие': 634,
#  'вечеринки': 635,
#  'наносят': 636,
#  'запись': 637,
#  'голоса': 638,
#  'барса': 639,
#  'наткнулся': 640,
#  'совершенно': 641,
#  'случайно': 642,
#  'хочется': 643,
#  'заплести': 644,
#  'бант': 645,
#  'косу': 646,
#  'надеть': 647,
#  'красивое': 648,
#  'платье': 649,
#  'два': 650,
#  'накопилась': 651,
#  'уйма': 652,
#  'вопросов': 653,
#  'которые': 654,
#  'ответить': 655,
#  'Врач': 656,
#  'прописал': 657,
#  'заживляющую': 658,
#  'мазь': 659,
#  'обработки': 660,
#  'раны': 661,
#  'Она': 662,
#  'успевала': 663,
#  'убраться': 664,
#  'разморозить': 665,
#  'фарш': 666,
#  'приготовить': 667,
#  'ужин': 668,
#  'нам': 669,
#  'слезал': 670,
#  'щупал': 671,
#  'стога': 672,
#  'узнать': 673,
#  'сухие': 674,
#  'ли': 675,
#  'деревнях': 676,
#  'по-прежнему': 677,
#  'мяли': 678,
#  'лен': 679,
#  'оставались': 680,
#  'непроезжими': 681,
#  'обнаружив': 682,
#  'досье': 683,
#  'сыщики': 684,
#  'решили': 685,
#  'рыть': 686,
#  'другом': 687,
#  'направлении': 688,
#  'Дрозды': 689,
#  'скворцы': 690,
#  'начали': 691,
#  'вить': 692,
#  'семейные': 693,
#  'неподалеку': 694,
#  'друг': 695,
#  'друга': 696,
#  'Собаку': 697,
#  'виновницу': 698,
#  'случившегося': 699,
#  'приказали': 700,
#  'сечь': 701,
#  'хотя': 702,
#  'чем': 703,
#  'ее': 704,
#  'вина': 705,
#  'С': 706,
#  'нескрываемой': 707,
#  'едкой': 708,
#  'иронией': 709,
#  'отзываются': 710,
#  'о': 711,
#  'друге': 712,
#  'Олень': 713,
#  'бродил': 714,
#  'среди': 715,
#  'берёз': 716,
#  'жевал': 717,
#  'талый': 718,
#  'поглядывал': 719,
#  'реку': 720,
#  'Приблизительно': 721,
#  'тайги': 722,
#  'мопед': 723,
#  'упал': 724,
#  'сугроб': 725,
#  'сломался': 726,
#  'Убедительно': 727,
#  'просим': 728,
#  'вас': 729,
#  'разборчиво': 730,
#  'заполнять': 731,
#  'купон': 732,
#  'желательно': 733,
#  'печатными': 734,
#  'буквами': 735,
#  'министром': 736,
#  'труда': 737,
#  'тянется': 738,
#  'шлейф': 739,
#  'финансовых': 740,
#  'скандалов': 741,
#  'А': 742,
#  'промывать': 743,
#  'манную': 744,
#  'крупу': 745,
#  'перед': 746,
#  'тем': 747,
#  'варить': 748,
#  'пробовали': 749,
#  'сказал': 750,
#  'русский': 751,
#  'солдат': 752,
#  'омоет': 753,
#  'сапоги': 754,
#  'Индийском': 755,
#  'океане': 756,
#  'знал:': 757,
#  'их': 758,
#  'особенно': 759,
#  'злило': 760,
#  'никуда': 761,
#  'бежал': 762,
#  'Приготовь': 763,
#  'диетические': 764,
#  'овощные': 765,
#  'блюда': 766,
#  'сытные': 767,
#  'восхитительные': 768,
#  'вкус': 769,
#  'Создать': 770,
#  'настоящие': 771,
#  'шедевры': 772,
#  'вам': 773,
#  'помогут': 774,
#  'зоркий': 775,
#  'глаз': 776,
#  'терпение': 777,
#  'упорство': 778,
#  'Ему': 779,
#  'удалось': 780,
#  'вскрыть': 781,
#  'банку': 782,
#  'об': 783,
#  'край': 784,
#  'бампера': 785,
#  'своего': 786,
#  'автомобиля': 787,
#  'По': 788,
#  'воскресеньям': 789,
#  'музыканты': 790,
#  'исполнявшие': 791,
#  'сонату': 792,
#  'собирались': 793,
#  'клубе': 794,
#  'Существуют': 795,
#  'микробы': 796,
#  'могут': 797,
#  'при': 798,
#  'температуре': 799,
#  'выше': 800,
#  'ста': 801,
#  'градусов': 802,
#  'Мы': 803,
#  'установили': 804,
#  'камеру': 805,
#  'новый': 806,
#  'штатив': 807,
#  'приступили': 808,
#  'съемкам': 809,
#  'Елена': 810,
#  'сидела': 811,
#  'кресле': 812,
#  'молодая': 813,
#  'Мурка': 814,
#  'урчала': 815,
#  'неё': 816,
#  'коленях': 817,
#  'никак': 818,
#  'суметь': 819,
#  'испечь': 820,
#  'торт': 821,
#  'самой': 822,
#  'речи': 823,
#  'учёного': 824,
#  'прозвучало': 825,
#  'неявное': 826,
#  'сопоставление': 827,
#  'другим': 828,
#  'знаменитым': 829,
#  'физиком': 830,
#  'люблю': 831,
#  'салат': 832,
#  'картошки': 833,
#  'зеленью': 834,
#  'заправленный': 835,
#  'пахучим': 836,
#  'подсолнечным': 837,
#  'маслом': 838,
#  'еще': 839,
#  'увижу': 840,
#  'хоть': 841,
#  'соринку': 842,
#  'уши': 843,
#  'оторву': 844,
#  'берегу': 845,
#  'появляются': 846,
#  'русалки': 847,
#  'ведьмы': 848,
#  'Под': 849,
#  'рукавом': 850,
#  'рубашки': 851,
#  'виднелся': 852,
#  'ремешок': 853,
#  'мужских': 854,
#  'часов': 855,
#  'вторичном': 856,
#  'рынке': 857,
#  'жилья': 858,
#  'розетки': 859,
#  'заклеивают': 860,
#  'обоями': 861,
#  'во': 862,
#  'ремонта': 863,
#  'досадой': 864,
#  'хмурила': 865,
#  'брови': 866,
#  'оглядываясь': 867,
#  'лесу': 868,
#  'ветром': 869,
#  'трепало': 870,
#  'стебли': 871,
#  'растений': 872,
#  'почерневшие': 873,
#  'летнего': 874,
#  'солнца': 875,
#  'Старый': 876,
#  'шкаф': 877,
#  'орехового': 878,
#  'дерева': 879,
#  'явно': 880,
#  'отсюда': 881,
#  'Старуха': 882,
#  'страшной': 883,
#  'лопоухая': 884,
#  'гнилыми': 885,
#  'зубами': 886,
#  'качестве': 887,
#  'примера': 888,
#  'приводится': 889,
#  'жирность': 890,
#  'куриного': 891,
#  'бульона': 892,
#  'сгущенки': 893,
#  'папа': 894,
#  'привозил': 895,
#  'стоило': 896,
#  'позвонить': 897,
#  'Вспоминая': 898,
#  'журчание': 899,
#  'водяных': 900,
#  'струй': 901,
#  'непременно': 902,
#  'подумаем': 903,
#  'фонтанах': 904,
#  'котёл': 905,
#  'бросают': 906,
#  'куски': 907,
#  'баранины': 908,
#  'специи': 909,
#  'травы': 910,
#  'Пашки': 911,
#  'обгорели': 912,
#  'ресницы': 913,
#  'щеки': 914,
#  'ходит': 915,
#  'намазанный': 916,
#  'кремом': 917,
#  'вскрыл': 918,
#  'пачку': 919,
#  'сухарей': 920,
#  'заварил': 921,
#  'достал': 922,
#  'чашки': 923,
#  'ложки': 924,
#  'Ее': 925,
#  'Гриша': 926,
#  'умер': 927,
#  'бездетным': 928,
#  'младший': 929,
#  'остался': 930,
#  'единственным': 931,
#  'наследником': 932,
#  'неопытным': 933,
#  'дипломатом': 934,
#  'большим': 935,
#  'мечтателем': 936,
#  'мои': 937,
#  'обязанности': 938,
#  'входило': 939,
#  'утром': 940,
#  'включить': 941,
#  'рубильник': 942,
#  'подвале': 943,
#  'После': 944,
#  'завершения': 945,
#  'техосмотра': 946,
#  'эксперты': 947,
#  'цену': 948,
#  'которой': 949,
#  'забрать': 950,
#  'автомобиль': 951,
#  'Прибывшие': 952,
#  'Австралию': 953,
#  'миссионеры': 954,
#  'расспрашивали': 955,
#  'жителей': 956,
#  'про': 957,
#  'пещеру': 958,
#  'океана': 959,
#  'Отвернув': 960,
#  'цветастое': 961,
#  'покрывало': 962,
#  'осторожно': 963,
#  'присела': 964,
#  'кровати': 965,
#  'почти': 966,
#  'слегка': 967,
#  'пополнела': 968,
#  'появились': 969,
#  'первые': 970,
#  'морщинки': 971,
#  'Журналист': 972,
#  'взял': 973,
#  'карандаш': 974,
#  'подвинул': 975,
#  'чистый': 976,
#  'лист': 977,
#  'написал': 978,
#  'цифру': 979,
#  'Считается': 980,
#  'коллекционирование': 981,
#  'раритетных': 982,
#  'машин': 983,
#  'занятие': 984,
#  'звезд': 985,
#  'шоу-бизнеса': 986,
#  'Торговля': 987,
#  'продуктами': 988,
#  'питания': 989,
#  'является': 990,
#  'одной': 991,
#  'самых': 992,
#  'прибыльных': 993,
#  'отраслей': 994,
#  'России': 995,
#  'Клиенты': 996,
#  'воровали': 997,
#  'ресторана': 998,
#  'атрибутику': 999,
#  ...}

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_corpus:
    indices = [word2idx[word] for word in sentence]
    # for each word, threated as center word
    for center_word_pos in range(len(indices)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            context_word_idx = indices[context_word_pos]
            idx_pairs.append((indices[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array

# %%
idx_pairs[:10]
# Out:
# array([[0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 2],
#        [1, 3],
#        [2, 0],
#        [2, 1],
#        [2, 3],
#        [2, 4],
#        [3, 1]])

# %%
def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x

# %%
embedding_dims = 5
W1 = Variable(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = Variable(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 1010
learning_rate = 0.001
losses = []

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = Variable(get_input_layer(data)).float()
        y_true = Variable(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        loss_val += loss.data.item()
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')
        losses.append(loss_val/len(idx_pairs))
# Out:
# Loss at epo 0: 9.191051271490663
# Loss at epo 10: 8.547357266345925
# Loss at epo 20: 8.227217359368268
# Loss at epo 30: 8.001356761160094
# Loss at epo 40: 7.82147472595838
# Loss at epo 50: 7.6711376073352175
# Loss at epo 60: 7.542080029147956
# Loss at epo 70: 7.429202985412327
# Loss at epo 80: 7.329023015767698
# Loss at epo 90: 7.239025192409495
# Loss at epo 100: 7.157330584252315
# Loss at epo 110: 7.082509985545479
# Loss at epo 120: 7.013459820242234
# Loss at epo 130: 6.9493153617689885
# Loss at epo 140: 6.889366663411337
# Loss at epo 150: 6.832996054760711
# Loss at epo 160: 6.779659439478735
# Loss at epo 170: 6.728897174474891
# Loss at epo 180: 6.680333318288859
# Loss at epo 190: 6.633660699365147
# Loss at epo 200: 6.58862689350517
# Loss at epo 210: 6.545026036957521
# Loss at epo 220: 6.502693694452892
# Loss at epo 230: 6.461497405347006
# Loss at epo 240: 6.421329721253191
# Loss at epo 250: 6.382102370649524
# Loss at epo 260: 6.343742008580854
# Loss at epo 270: 6.306187693843137
# Loss at epo 280: 6.269388522236144
# Loss at epo 290: 6.23330279386746
# Loss at epo 300: 6.1978971332737745
# Loss at epo 310: 6.163141576221384
# Loss at epo 320: 6.129013224306356
# Loss at epo 330: 6.095494708159302
# Loss at epo 340: 6.062570950639413
# Loss at epo 350: 6.030229193737902
# Loss at epo 360: 5.998460426771661
# Loss at epo 370: 5.967255137893057
# Loss at epo 380: 5.936603286482742
# Loss at epo 390: 5.906496003418645
# Loss at epo 400: 5.876923244304478
# Loss at epo 410: 5.847874731851977
# Loss at epo 420: 5.819337060878398
# Loss at epo 430: 5.79129593832938
# Loss at epo 440: 5.763735425979726
# Loss at epo 450: 5.736640129076959
# Loss at epo 460: 5.7099945386500455
# Loss at epo 470: 5.683780490913052
# Loss at epo 480: 5.657981328827618
# Loss at epo 490: 5.632580440420418
# Loss at epo 500: 5.607561312260774
# Loss at epo 510: 5.582906772109778
# Loss at epo 520: 5.558600512809367
# Loss at epo 530: 5.5346273683218135
# Loss at epo 540: 5.510972540832062
# Loss at epo 550: 5.487621474572081
# Loss at epo 560: 5.464561255219388
# Loss at epo 570: 5.441780399853942
# Loss at epo 580: 5.419267518113349
# Loss at epo 590: 5.397012356029536
# Loss at epo 600: 5.375005987865053
# Loss at epo 610: 5.3532384706134915
# Loss at epo 620: 5.331702476615923
# Loss at epo 630: 5.3103909186463625
# Loss at epo 640: 5.289297030641467
# Loss at epo 650: 5.268415700702361
# Loss at epo 660: 5.247741078612503
# Loss at epo 670: 5.22726838856264
# Loss at epo 680: 5.206993685438067
# Loss at epo 690: 5.186912339819883
# Loss at epo 700: 5.167019834370712
# Loss at epo 710: 5.147313622670632
# Loss at epo 720: 5.127790372192447
# Loss at epo 730: 5.108448774371444
# Loss at epo 740: 5.089285777013368
# Loss at epo 750: 5.0702989344812766
# Loss at epo 760: 5.051485104760739
# Loss at epo 770: 5.032842846713199
# Loss at epo 780: 5.014370662474962
# Loss at epo 790: 4.996067285021215
# Loss at epo 800: 4.977930679478306
# Loss at epo 810: 4.959959942376179
# Loss at epo 820: 4.942153521437373
# Loss at epo 830: 4.924510159799296
# Loss at epo 840: 4.907028845861632
# Loss at epo 850: 4.889708700933634
# Loss at epo 860: 4.872547620478081
# Loss at epo 870: 4.855545307788836
# Loss at epo 880: 4.838701457792387
# Loss at epo 890: 4.822014917830971
# Loss at epo 900: 4.8054840306217175
# Loss at epo 910: 4.7891085369309065
# Loss at epo 920: 4.772888987765775
# Loss at epo 930: 4.756823484338756
# Loss at epo 940: 4.740911740674097
# Loss at epo 950: 4.725153073487704
# Loss at epo 960: 4.709546531416618
# Loss at epo 970: 4.694090835995443
# Loss at epo 980: 4.678784462450592
# Loss at epo 990: 4.663626873475117
# Loss at epo 1000: 4.648617651901067

# %%
plt.plot(list(range(0, num_epochs, 10)), losses)
